# %%
import dlt

# %%
pipeline = dlt.pipeline(
    pipeline_name="resource_source", 
    destination="duckdb", 
    dataset_name="mydata", 
    dev_mode=True
)

# %%
data = [
    {"id": "1", "name": "bulbasaur", "size": {"weight": 6.9, "height": 0.7}},
    {"id": "4", "name": "charmander", "size": {"weight": 8.5, "height": 0.6}},
    {"id": "25", "name": "pikachu", "size": {"weight": 6, "height": 0.4}},
]

load_data = pipeline.run(data, table_name="pokemon")
print(load_data)
# Out:
# Pipeline resource_source load step completed in 1.52 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset mydata_20250215080417
# The duckdb destination used duckdb:////home/myothet/repos/data-engineering/dlt/resource_source.duckdb location to store data
# Load package 1739606660.2588902 is LOADED and contains no failed jobs

# %%
import duckdb

# %%
# 1. dlt - duckdb connection

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

conn.sql(f"SET search_path = '{pipeline.dataset_name}'")

conn.sql("DESCRIBE").df()
# Out:
#            database                 schema                 name  \
# 0   resource_source  mydata_20250213121604           _dlt_loads
# 1   resource_source  mydata_20250213121604  _dlt_pipeline_state
# 2   resource_source  mydata_20250213121604         _dlt_version
# 3   resource_source  mydata_20250213121604              pokemon
# 4   resource_source  mydata_20250215075752           _dlt_loads
# 5   resource_source  mydata_20250215075752  _dlt_pipeline_state
# 6   resource_source  mydata_20250215075752         _dlt_version
# 7   resource_source  mydata_20250215075752              pokemon
# 8   resource_source  mydata_20250215080417           _dlt_loads
# 9   resource_source  mydata_20250215080417  _dlt_pipeline_state
# 10  resource_source  mydata_20250215080417         _dlt_version
# 11  resource_source  mydata_20250215080417              pokemon
#
#                                          column_names  \
# 0   [load_id, schema_name, status, inserted_at, sc...
# 1   [version, engine_version, pipeline_name, state...
# 2   [version, engine_version, inserted_at, schema_...
# 3   [id, name, size__weight, size__height, _dlt_lo...
# 4   [load_id, schema_name, status, inserted_at, sc...
# 5   [version, engine_version, pipeline_name, state...
# 6   [version, engine_version, inserted_at, schema_...
# 7   [id, name, size__weight, size__height, _dlt_lo...
# 8   [load_id, schema_name, status, inserted_at, sc...
# 9   [version, engine_version, pipeline_name, state...
# 10  [version, engine_version, inserted_at, schema_...
# 11  [id, name, size__weight, size__height, _dlt_lo...
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3   [VARCHAR, VARCHAR, DOUBLE, DOUBLE, VARCHAR, VA...      False
# 4   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 5   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 6   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 7   [VARCHAR, VARCHAR, DOUBLE, DOUBLE, VARCHAR, VA...      False
# 8   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 9   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 10  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 11  [VARCHAR, VARCHAR, DOUBLE, DOUBLE, VARCHAR, VA...      False

# %%
table = conn.sql("SELECT * FROM pokemon").df()

table
# Out:
#    id        name  size__weight  size__height        _dlt_load_id  \
# 0   1   bulbasaur           6.9           0.7  1739606660.2588902
# 1   4  charmander           8.5           0.6  1739606660.2588902
# 2  25     pikachu           6.0           0.4  1739606660.2588902
#
#           _dlt_id
# 0  It5UZX4LGvixbQ
# 1  +5qH9FRbSdWUog
# 2  kXOheZAmpMkBbQ

# %%
# 2. dlt - sql_client

with pipeline.sql_client() as client:
    with client.execute_query("SELECT * FROM pokemon") as cursor:
        data = cursor.df()

data
# Out:
#    id        name  size__weight  size__height        _dlt_load_id  \
# 0   1   bulbasaur           6.9           0.7  1739606660.2588902
# 1   4  charmander           8.5           0.6  1739606660.2588902
# 2  25     pikachu           6.0           0.4  1739606660.2588902
#
#           _dlt_id
# 0  It5UZX4LGvixbQ
# 1  +5qH9FRbSdWUog
# 2  kXOheZAmpMkBbQ

# %%
# 3. dlt - datasets 

dataset = pipeline.dataset(dataset_type="default")
dataset.pokemon.df()
# Out:
#    id        name  size__weight  size__height        _dlt_load_id  \
# 0   1   bulbasaur           6.9           0.7  1739606660.2588902
# 1   4  charmander           8.5           0.6  1739606660.2588902
# 2  25     pikachu           6.0           0.4  1739606660.2588902
#
#           _dlt_id
# 0  It5UZX4LGvixbQ
# 1  +5qH9FRbSdWUog
# 2  kXOheZAmpMkBbQ

# %%
# Exercise - count the number of columns in the table
print(len(dataset.pokemon.columns_schema))

print(dataset.pokemon.df().count().count())
# Out:
# 6
# 6
